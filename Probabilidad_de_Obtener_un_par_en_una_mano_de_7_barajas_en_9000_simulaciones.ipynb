# %% [markdown]
# <a href="https://colab.research.google.com/github/dorianivc/Programacion-Dinamica-y-Estocastica-con-Python/blob/master/Probabilidad_de_Obtener_un_par_en_una_mano_de_7_barajas_en_9000_simulaciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import collections
from bokeh.plotting import figure, show

PALOS =['espada', 'corazon,', 'rombo', 'trebol']
VALORES=['as','2','3','4','5','6','7','8','9','10','jota','reina','rey']

def crear_baraja():
    barajas=[]
    for palo in PALOS:
        for valor in VALORES:
            barajas.append((palo,valor))
    
    return barajas

def obtener_mano(barajas, tamano_mano):
    mano=random.sample(barajas, tamano_mano)
    return mano

def plot(sim, prob, tam):
    plot = figure(title=f'Probabilidad de obtener un par en una mano de tamaño {tam} / Probability of getting a pair in a hand of size {tam} ',x_axis_label="Intentos/Attempts",y_axis_label='Probabilidad/ Probability')
    plot.line(sim, prob)
    show(plot)

def main(tamano_mano,intentos):
    barajas=crear_baraja()

    manos=[]
    for _ in range(intentos):
        mano= obtener_mano(barajas,tamano_mano)
        manos.append(mano)
    
    pares=0
    for mano in manos:
        valores=[]
        for carta in mano:
            valores.append(carta[1])

        counter=dict(collections.Counter(valores))
        for val in counter.values():
            if val==2:
                pares +=1
                break
    
    probabilidad_par= pares/intentos
    print(f'La probabilidad de obtener un par en una mano de {tamano_mano} barajas es , {probabilidad_par}')
    return probabilidad_par




if __name__=='__main__':
    tamano_mano=int(input('De cuantas barajas, sera la mano: '))
    intentos = int(input('Cuantos intentos para calcular la probabilidad: '))
    simulaciones=[]
    probabilidad=[]
    for i in range(1, intentos):
        simulaciones.append(main(tamano_mano,intentos))
        probabilidad.append(i)
    plot(probabilidad, simulaciones, tamano_mano)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7288888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7355555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.742
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7391111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7382222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7365555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7454444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7401111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.736
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7398888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7417777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.745
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7426666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7355555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7336666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7356666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7404444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7345555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7355555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7395555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7446666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7414444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7401111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.734
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7335555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7398888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7357777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7386666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7374444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.742
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7382222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7345555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7345555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7405555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7364444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7351111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7386666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7404444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7358888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7351111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7417777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7433333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7396666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7393333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7406666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7424444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7435555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7424444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7374444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7408888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7351111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7471111111111111
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7483333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.737
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7362222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.744
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7336666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7387777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7472222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7332222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7418888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7352222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7336666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7393333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7372222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7352222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7281111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7404444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7267777777777777
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7267777777777777
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7337777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7462222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7367777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7375555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7396666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7333333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7375555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7376666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7342222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7448888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7397777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7356666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7413333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7348888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.745
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7418888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7411111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7372222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7387777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7427777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7336666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7423333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7331111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7386666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.744
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7383333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7453333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7367777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7417777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7395555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.738
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7336666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7415555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7307777777777777
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7351111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7364444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7417777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7423333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.732
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7412222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7333333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7384444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7401111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7451111111111111
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7324444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7361111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7455555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7371111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7385555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7435555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7395555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7352222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7434444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7412222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.742
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7368888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7418888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.738
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7408888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7364444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7347777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.748
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7384444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7398888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.728
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7333333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7434444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7462222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.74
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7395555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7415555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7361111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7417777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7315555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7364444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.743
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7403333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7368888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7358888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7376666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7387777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7374444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7371111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7398888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.739
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.735
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.739
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7434444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7337777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7327777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7361111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7388888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7415555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7494444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7341111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7422222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7385555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.748
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7402222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7342222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.738
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7468888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7472222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7282222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.737
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7374444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7278888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7285555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7374444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7322222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7431111111111111
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7417777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7398888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7413333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7388888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7263333333333334
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7384444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7401111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7387777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7315555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7391111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7385555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7383333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7378888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7358888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7436666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7417777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7397777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7405555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7443333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7408888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.735
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7368888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7378888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7374444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7381111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7431111111111111
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7394444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7425555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7393333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7422222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7331111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7336666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7374444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7374444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7364444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.738
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7406666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7331111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7298888888888889
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.737
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7366666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.74
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7424444444444445
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7436666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7361111111111112
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7366666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7392222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7343333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.739
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7353333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7367777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7377777777777778
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7405555555555555
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7413333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7442222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7396666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7362222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7453333333333333
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7392222222222222
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.7426666666666667
# La probabilidad de obtener un par en una mano de 7 barajas es , 0.